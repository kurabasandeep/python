# %% [markdown]
# #

# %% [markdown]
# Data visualization

# %%
# import matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
file_path='C:/Users/YUVA KISHORE/Downloads/mtcars2.csv'
#jupytar_notebook=C:/Users/YUVA KISHORE/Downloads/mtcars2.csv'
cars=pd.read_csv(file_path)
print (cars)
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4           Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 6               Valiant  18.1    6  225.0  105  2.76  3.460  17.02   1   0
# 7            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 8             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 9              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# ...

# %%
file_path_1='C:/Users/YUVA KISHORE/Documents/Sample-Superstore.xlsx'
data = pd.read_excel(file_path_1)
print(data)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
#see how hp varies with each car with line plot
import matplotlib.pyplot as plt
# %matplotlib inline
y=cars['hp']
x=range(44)
plt.plot(x,y)
plt.show()

# %%
# %matplotlib inline

x=cars['wt']
count=cars['cyl']>6
plt.pie(count,x)
plt.show()

# %%
import matplotlib.pyplot as plt

#changpt given this list


# Assuming 'cars' is a DataFrame and has an 'hp' column
y = cars['hp']
x = range(44)  # or len(cars) if dynamically determined
plt.plot(x, y)
#plt.xlabel('Car Index')
#plt.ylabel('Horsepower (hp)')
#plt.title('Horsepower Variation by Car')
#plt.show()

# %%
# Assuming 'cars' is a DataFrame and has an 'hp' column
y = cars['hp']
x = range(44)  # or len(cars) if dynamically determined
#plt.plot(x, y)
plt.xlabel('Car Index')
#plt.ylabel('Horsepower (hp)')
#plt.title('Horsepower Variation by Car')
#plt.show()
# Out:
# Text(0.5, 0, 'Car Index')

# %%
# Assuming 'cars' is a DataFrame and has an 'hp' column
y = cars['hp']
x = range(44)  # or len(cars) if dynamically determined
#plt.plot(x, y)
#plt.xlabel('Car Index')
plt.ylabel('Horsepower (hp)')
#plt.title('Horsepower Variation by Car')
#plt.show()
# Out:
# Text(42.597222222222214, 0.5, 'Horsepower (hp)')

# %%
# Assuming 'cars' is a DataFrame and has an 'hp' column
y = cars['hp']
x = range(44)  # or len(cars) if dynamically determined
#plt.plot(x, y)
#plt.xlabel('Car Index')
#plt.ylabel('Horsepower (hp)')
plt.title('Horsepower Variation by Car')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Horsepower Variation by Car')

# %%
# Assuming 'cars' is a DataFrame and has an 'hp' column
y = cars['hp']
x = range(44)  # or len(cars) if dynamically determined
plt.plot(x, y)
plt.xlabel('Car Index')
plt.ylabel('Horsepower (hp)')
plt.title('Horsepower Variation by Car')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'cars' is a DataFrame and 'hp' is one of its columns
y = cars['hp']  # 'hp' column data
x = range(len(cars))  # Adjusting range dynamically to the DataFrame length

# Plotting
plt.plot(x, y, color='red', linestyle=':', marker='o', label='HP Data')

#plt.plot(x, y, marker='o',)rs for clarity
plt.xlabel('Car Index')  # X-axis label
plt.ylabel('Horsepower (hp)')  # Y-axis label
plt.title('Horsepower Variation by Car')  # Chart title
plt.grid(True)  # Optional: Adds a grid to the chart
plt.show()  # Displays the chart

# %%
import matplotlib.pyplot as plt

# Assuming 'cars' is a DataFrame and 'hp' is one of its columns
y = cars['hp']  # 'hp' column data
x = range(len(cars))  # Adjusting range dynamically to the DataFrame length

# Plotting
plt.plot(x, y, marker='o')  # Added markers for clarity
plt.xlabel('Car Index')  # X-axis label
plt.ylabel('Horsepower (hp)')  # Y-axis label
plt.title('Horsepower Variation by Car')  # Chart title
plt.grid(False)  # Optional: plain chat to the chart 
plt.show()  # Displays the chart

# %%
# input type trying 

#y=cars['mpg']

#x=int(input())
start = int(input("Enter the starting value for the X-axis range: "))
end = int(input("Enter the ending value for the X-axis range: "))
x = range(start, end + 1)  # Adding 1 to include the ending value
y = [i * 10 for i in x]  # Example Y values (double the X values)
plt.plot(x,y)
plt.show()
# Out:
# Enter the starting value for the X-axis range:  10
# Enter the ending value for the X-axis range:  20

# %%
# chatgpt 

import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrame (replace this with your actual data)
data = {
    'hp': [120, 150, 100, 200, 180, 110, 130, 160, 170, 140, 
           125, 155, 135, 145, 175, 190, 115, 105, 185, 195,
           200, 145, 155, 165, 135, 175, 185, 195, 125, 115,
           105, 195, 140, 110, 130, 160, 170, 140, 180, 190,
           200, 150, 120, 130]
}
cars = pd.DataFrame(data)

# User input for range
start = int(input("Enter the starting index: "))  # For example: 5
end = int(input("Enter the ending index: "))      # For example: 15

# Ensure valid input
if start < 0 or end >= len(cars['hp']) or start > end:
    print("Invalid range. Please enter indices between 0 and", len(cars['hp']) - 1)
else:
    # Generate X and subset Y based on user input
    x = range(start, end + 1)  # X-axis range based on input
    y = cars['hp'][start:end + 1]  # Y-axis values corresponding to the range

    # Plot the graph
    plt.plot(x, y, color='blue', linestyle='--', marker='o', label='Horsepower (hp)')
    plt.xlabel('Car Index')
    plt.ylabel('Horsepower (hp)')
    plt.title('Horsepower Variation by Car (Dynamic Range)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Enter the starting index:  20
# Enter the ending index:  30

# %%
# chatgpt 
import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrame (replace this with your actual data)
data = {
    'hp': [120, 150, 100, 200, 180, 110, 130, 160, 170, 140, 
           125, 155, 135, 145, 175, 190, 115, 105, 185, 195,
           200, 145, 155, 165, 135, 175, 185, 195, 125, 115,
           105, 195, 140, 110, 130, 160, 170, 140, 180, 190,
           200, 150, 120, 130]
}
cars = pd.DataFrame(data)

# User input for range
start = int(input("Enter the starting index: "))  # For example: 5
end = int(input("Enter the ending index: "))      # For example: 15

# Ensure valid input
if start < 0 or end >= len(cars['hp']): # or start > end:
    print("Invalid range. Please enter indices between 0 and", len(cars['hp']) - 1)
else:
    # Generate X and subset Y based on user input
    x = range(start, end + 1)  # X-axis range based on input
    y = cars['hp'][start:end + 1]  # Y-axis values corresponding to the range

    # Plot the graph
    plt.plot(x, y, color='blue', linestyle='--', marker='o', label='Horsepower (hp)')
    plt.xlabel('Car Index')
    plt.ylabel('Horsepower (hp)')
    plt.title('Horsepower Variation by Car (Dynamic Range)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Enter the starting index:  30
# Enter the ending index:  20

# %%
import numpy as np
x=np.arange(0,10,1)
y=2*x + 5

# %matplotlib inline
plt.plot(x,y)
plt.show()

# %%
import numpy as np
x=np.arange(0,10,1)
y=2*x + 5

# %matplotlib inline
plt.plot(x,y,color='green', marker='*')
plt.show()

# %%
x=np.arange(0,50,1)
y=np.arange(0,50,1)

# %matplotlib inline
plt.plot(x,y,color='green', marker='h')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 x=np.arange(0,50,1)
#       2 y=np.arange(0,50,1)
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# NameError: name 'np' is not defined

# %%
x=np.arange(0,10,1)
y=2 * x + 5
fig=plt.figure(figsize=(10,5))
plt.plot(x, y, color='r', linestyle='--', marker='o',alpha=1.0,linewidth=2.0,markerfacecolor='green')
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("line plot demo")
plt.legend(['line1'],loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# line chart

# %%
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+5
plt.plot(x,y1,color='g')
plt.title('graph1')

plt.plot(x,y2,color='r')
plt.title('graph2')
plt.show()

# %%
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+5
plt.subplot(2,1,1)
plt.plot(x,y1,color='g')
plt.title('graph1')

plt.subplot(2,1,2)

plt.plot(x,y2,color='r')
plt.title('graph2')
plt.show()

# %%
x=np.arange(0,10,1)
y1=2*x+5
y2=3*x+5
plt.subplot(1,2,1)
plt.plot(x,y1,color='g')
plt.title('graph1')

plt.subplot(1,2,2)

plt.plot(x,y2,color='r')
plt.title('graph2')
plt.show()

# %%
#import matplotlib
import matplotlib.pyplot  as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
x  = range(44)
#area plot of hp and disp
plt.stackplot(y,y2)#,colors = 'r', alpha = 0.7)
plt.stackplot(x,y2)#,colors = 'c', alpha = 0.5)
plt.show()

# %% [markdown]
# BAR CHAT (VERTICAL AND HORIGENTAL)

# %%
#import matplotlib
import matplotlib.pyplot  as plt
# %matplotlib inline
y = cars['hp']
x  = range(32)
#model to list
x1 = cars['cyl'].tolist()
#adding figure to adjust figsize
fig = plt.figure(figsize = (10,5))
#see how hp changes with bar plot
plt.bar(x1,y,color="purple")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
x=[20,30,50]
y=[1,8,10]

plt.bar(x,y,color=('g','r','y'))
plt.show()

# %%
x=[20,30,50]
y=[1,8,10]

plt.barh(x,y,color=('g','r','y'))
plt.show()

# %% [markdown]
# Scatter Plot chart

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
a=[10,20,30,40,50,60,70,80]
b=[4,3,5,8,6,9,10,7]
c=[2,6,8,9,3,7,3,1]

plt.scatter(a,b)
plt.scatter(a,c)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
a=[10,20,30,40,50,60,70,80]
b=[4,3,5,8,6,9,10,7]
c=[2,6,8,9,3,7,3,1]

plt.scatter(a,b,c='g')
plt.scatter(a,c ,c='b')
#plt.xlable("x-axis")
plt.grid(True)
plt.show()

# %% [markdown]
# histogram chart

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
age=[10,20,50,47,30,896,100,32,26,89,10,11,1,12,13,15]
plt.hist(age,bins=[0,20,40,60,80,100] ,color="g")
plt.savefig("histogram plot.pdf")
plt.show()

# %% [markdown]
# PIE CHART

# %%
animals=['cow','monkey','fish','tiger']
count=[20,30,40,50]

plt.pie(count,labels=animals)

plt.title("pie chart demo")
plt.show()

# %%
plt.pie(count,labels=animals,autopct='%1.1f%%',shadow=True,startangle=90,explode=(0,0.1,0,0,))
plt.title("pie chart demo")
plt.show()

# %% [markdown]
# Donut Chart

# %%
animals=['cow','monkey','fish','tiger']
count=[20,30,40,50]
size_center=[10]

pie1=plt.pie(count,labels=animals,radius=1.5)
pie2=plt.pie(size_center,radius=1.0,colors='w')
plt.title("pie chart demo")
plt.show()

# %%
import matplotlib.pyplot  as plt
# %matplotlib inline
y1 = range(1,15)
y2 = [1,2,3,7,9,5,7,9,6,7,2,4,5,2]

#plot both line plot and area plot to see the margin
plt.plot(y2,y1, linewidth = 2.0, color = 'r')
plt.stackplot(y2,y1,colors = 'gold', alpha = 0.7)

plt.show()

# %% [markdown]
# ##
